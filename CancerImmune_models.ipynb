# %%
using Distributions, DataFrames,  Plots, ODE
# Out:
# INFO: Precompiling module Distributions.
# INFO: Precompiling module DataFrames.
# INFO: Precompiling module Plots.
# INFO: Precompiling module ODE.

# %%
# population grows according to birthrate and cell number
# dN/dt = b*N
# population gets killed with function according to neoep burden, cell number, additional immune par

# %%
f(s, rMax, kLim, a) = rMax./(1+exp.(-a*(s-kLim)))
plot(0:0.05:1000, f(0:0.05:1000, 10, 200, 0.02))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip4800">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4801">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4800)" points="
# 22.4386,375.869 580.315,375.869 580.315,11.811 22.4386,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4802">
#     <rect x="22" y="11" width="559" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   22.4386,375.869 22.4386,11.811
#   "/>
# ...

# %%
f(u,p,t) = 1.01*u
u0=1/2
tspan = (0.0,1.0)
prob = ODEProblem(f,u0,tspan)
sol = solve(prob,ode45(),reltol=1e-8,abstol=1e-8)

plot(sol,linewidth=5,title="Solution to the linear ODE with a thick line",
     xaxis="Time (t)",yaxis="u(t) (in μm)",label="My Thick Line!") # legend=false
plot!(sol.t, t->0.5*exp(1.01t),lw=3,ls=:dash,label="True Solution!")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1300">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1301">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1300)" points="
# 48.2225,360.121 580.315,360.121 580.315,31.4961 48.2225,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1302">
#     <rect x="48" y="31" width="533" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,360.121 48.2225,31.4961
#   "/>
# ...
